# %% [markdown]
# <a href="https://colab.research.google.com/github/nabihsabeh85/neural-network-challenge-2/blob/main/attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense

# %%
# Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# 0               3  ...                  3                        1
# 1               2  ...                  4                        4
# 2               2  ...                  3                        2
# 3               3  ...                  3                        3
# 4               3  ...                  3                        4
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                 8                      0               1
# 1                 1                10                      3               3
# 2                 0                 7                      3               3
# 3                 0                 8                      3               3
# 4                 1                 6                      3               3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 27 columns]

# %%
# Determine the number of unique values in each column
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]

# Create a list of 10 columns to use as X data
X_columns = ['Age', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction',
             'JobInvolvement', 'JobSatisfaction', 'NumCompaniesWorked',
             'PerformanceRating', 'RelationshipSatisfaction', 'YearsAtCompany']

# Create X_df using the selected columns
X_df = attrition_df[X_columns]

# Show the data types for X_df
X_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   DistanceFromHome          1470 non-null   int64
#  2   Education                 1470 non-null   int64
#  3   EnvironmentSatisfaction   1470 non-null   int64
#  4   JobInvolvement            1470 non-null   int64
#  5   JobSatisfaction           1470 non-null   int64
#  6   NumCompaniesWorked        1470 non-null   int64
#  7   PerformanceRating         1470 non-null   int64
#  8   RelationshipSatisfaction  1470 non-null   int64
#  9   YearsAtCompany            1470 non-null   int64
# dtypes: int64(10)
# memory usage: 115.0 KB

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, random_state=1)

# %%
# Convert X data to numeric data types
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# %%
# Create a OneHotEncoder for the Department column
dept_encoder = OneHotEncoder()
dept_encoder.fit(y_train[['Department']])

# Transform the Department column in the training and testing data
y_train_dept = dept_encoder.transform(y_train[['Department']]).toarray()
y_test_dept = dept_encoder.transform(y_test[['Department']]).toarray()

# %%
# Create a OneHotEncoder for the Attrition column
attr_encoder = OneHotEncoder()
attr_encoder.fit(y_train[['Attrition']])

# Transform the Attrition column in the training and testing data
y_train_attr = attr_encoder.transform(y_train[['Attrition']]).toarray()
y_test_attr = attr_encoder.transform(y_test[['Attrition']]).toarray()

# %%
# Create a StandardScaler and fit it to the training data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Find the number of columns in the X training data
num_columns = len(X_train_scaled[0])

# Create the input layer
input_layer = Input(shape=(num_columns,))

# Create the shared layers
shared1 = Dense(64, activation='relu')(input_layer)
shared2 = Dense(32, activation='relu')(shared1)

# Create the Department output branch
dept_hidden = Dense(16, activation='relu')(shared2)
dept_output = Dense(y_train_dept.shape[1], activation='softmax', name='department_output')(dept_hidden)

# Create the Attrition output branch
attr_hidden = Dense(16, activation='relu')(shared2)
attr_output = Dense(y_train_attr.shape[1], activation='sigmoid', name='attrition_output')(attr_hidden)

# Create the model
model = Model(inputs=input_layer, outputs=[dept_output, attr_output])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss={'department_output': 'categorical_crossentropy',
                    'attrition_output': 'binary_crossentropy'},
              metrics=['accuracy'])

# Summarize the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 10)]                 0         []
#
#  dense (Dense)               (None, 64)                   704       ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 32)                   2080      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 16)                   528       ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 16)                   528       ['dense_1[0][0]']
#
#  department_output (Dense)   (None, 3)                    51        ['dense_2[0][0]']
#
#  attrition_output (Dense)    (None, 2)                    34        ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 3925 (15.33 KB)
# Trainable params: 3925 (15.33 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Train the model
model.fit(X_train_scaled,
          {'department_output': y_train_dept, 'attrition_output': y_train_attr},
          epochs=50,
          batch_size=32,
          verbose=1)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 2s 8ms/step - loss: 1.6155 - department_output_loss: 0.9970 - attrition_output_loss: 0.6185 - department_output_accuracy: 0.5626 - attrition_output_accuracy: 0.7142
# Epoch 2/50
# 35/35 [==============================] - 0s 6ms/step - loss: 1.2621 - department_output_loss: 0.8127 - attrition_output_loss: 0.4494 - department_output_accuracy: 0.6479 - attrition_output_accuracy: 0.8466
# Epoch 3/50
# 35/35 [==============================] - 0s 6ms/step - loss: 1.1932 - department_output_loss: 0.7748 - attrition_output_loss: 0.4184 - department_output_accuracy: 0.6552 - attrition_output_accuracy: 0.8466
# Epoch 4/50
# 35/35 [==============================] - 0s 6ms/step - loss: 1.1758 - department_output_loss: 0.7654 - attrition_output_loss: 0.4104 - department_output_accuracy: 0.6579 - attrition_output_accuracy: 0.8466
# Epoch 5/50
# 35/35 [==============================] - 0s 5ms/step - loss: 1.1642 - department_output_loss: 0.7595 - attrition_output_loss: 0.4048 - department_output_accuracy: 0.6561 - attrition_output_accuracy: 0.8466
# Epoch 6/50
# 35/35 [==============================] - 0s 5ms/step - loss: 1.1514 - department_output_loss: 0.7503 - attrition_output_loss: 0.4011 - department_output_accuracy: 0.6633 - attrition_output_accuracy: 0.8466
# Epoch 7/50
# 35/35 [==============================] - 0s 4ms/step - loss: 1.1415 - department_output_loss: 0.7442 - attrition_output_loss: 0.3973 - department_output_accuracy: 0.6652 - attrition_output_accuracy: 0.8466
# Epoch 8/50
# 35/35 [==============================] - 0s 4ms/step - loss: 1.1314 - department_output_loss: 0.7377 - attrition_output_loss: 0.3937 - department_output_accuracy: 0.6688 - attrition_output_accuracy: 0.8466
# Epoch 9/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.1211 - department_output_loss: 0.7302 - attrition_output_loss: 0.3909 - department_output_accuracy: 0.6751 - attrition_output_accuracy: 0.8466
# Epoch 10/50
# 35/35 [==============================] - 0s 4ms/step - loss: 1.1169 - department_output_loss: 0.7291 - attrition_output_loss: 0.3878 - department_output_accuracy: 0.6770 - attrition_output_accuracy: 0.8466
# Epoch 11/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.1047 - department_output_loss: 0.7202 - attrition_output_loss: 0.3845 - department_output_accuracy: 0.6779 - attrition_output_accuracy: 0.8466
# Epoch 12/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0949 - department_output_loss: 0.7127 - attrition_output_loss: 0.3822 - department_output_accuracy: 0.6815 - attrition_output_accuracy: 0.8466
# Epoch 13/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0869 - department_output_loss: 0.7085 - attrition_output_loss: 0.3784 - department_output_accuracy: 0.6869 - attrition_output_accuracy: 0.8466
# Epoch 14/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0767 - department_output_loss: 0.7018 - attrition_output_loss: 0.3749 - department_output_accuracy: 0.6887 - attrition_output_accuracy: 0.8475
# Epoch 15/50
# 35/35 [==============================] - 0s 4ms/step - loss: 1.0672 - department_output_loss: 0.6951 - attrition_output_loss: 0.3721 - department_output_accuracy: 0.6960 - attrition_output_accuracy: 0.8494
# Epoch 16/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0604 - department_output_loss: 0.6915 - attrition_output_loss: 0.3689 - department_output_accuracy: 0.6933 - attrition_output_accuracy: 0.8521
# Epoch 17/50
# 35/35 [==============================] - 0s 4ms/step - loss: 1.0544 - department_output_loss: 0.6888 - attrition_output_loss: 0.3656 - department_output_accuracy: 0.6960 - attrition_output_accuracy: 0.8512
# Epoch 18/50
# 35/35 [==============================] - 0s 4ms/step - loss: 1.0457 - department_output_loss: 0.6833 - attrition_output_loss: 0.3624 - department_output_accuracy: 0.6951 - attrition_output_accuracy: 0.8566
# Epoch 19/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0350 - department_output_loss: 0.6765 - attrition_output_loss: 0.3585 - department_output_accuracy: 0.7105 - attrition_output_accuracy: 0.8639
# Epoch 20/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0233 - department_output_loss: 0.6686 - attrition_output_loss: 0.3548 - department_output_accuracy: 0.7187 - attrition_output_accuracy: 0.8621
# Epoch 21/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0128 - department_output_loss: 0.6610 - attrition_output_loss: 0.3518 - department_output_accuracy: 0.7187 - attrition_output_accuracy: 0.8621
# Epoch 22/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0118 - department_output_loss: 0.6620 - attrition_output_loss: 0.3498 - department_output_accuracy: 0.7169 - attrition_output_accuracy: 0.8657
# Epoch 23/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9990 - department_output_loss: 0.6533 - attrition_output_loss: 0.3457 - department_output_accuracy: 0.7142 - attrition_output_accuracy: 0.8693
# Epoch 24/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9901 - department_output_loss: 0.6477 - attrition_output_loss: 0.3424 - department_output_accuracy: 0.7341 - attrition_output_accuracy: 0.8657
# Epoch 25/50
# 35/35 [==============================] - 0s 4ms/step - loss: 0.9789 - department_output_loss: 0.6407 - attrition_output_loss: 0.3382 - department_output_accuracy: 0.7323 - attrition_output_accuracy: 0.8693
# Epoch 26/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9726 - department_output_loss: 0.6369 - attrition_output_loss: 0.3356 - department_output_accuracy: 0.7377 - attrition_output_accuracy: 0.8684
# Epoch 27/50
# 35/35 [==============================] - 0s 4ms/step - loss: 0.9620 - department_output_loss: 0.6272 - attrition_output_loss: 0.3347 - department_output_accuracy: 0.7423 - attrition_output_accuracy: 0.8793
# Epoch 28/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9539 - department_output_loss: 0.6230 - attrition_output_loss: 0.3308 - department_output_accuracy: 0.7459 - attrition_output_accuracy: 0.8748
# Epoch 29/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9408 - department_output_loss: 0.6150 - attrition_output_loss: 0.3258 - department_output_accuracy: 0.7505 - attrition_output_accuracy: 0.8766
# Epoch 30/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9306 - department_output_loss: 0.6075 - attrition_output_loss: 0.3231 - department_output_accuracy: 0.7459 - attrition_output_accuracy: 0.8775
# Epoch 31/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9279 - department_output_loss: 0.6043 - attrition_output_loss: 0.3236 - department_output_accuracy: 0.7495 - attrition_output_accuracy: 0.8766
# Epoch 32/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9243 - department_output_loss: 0.6045 - attrition_output_loss: 0.3198 - department_output_accuracy: 0.7450 - attrition_output_accuracy: 0.8784
# Epoch 33/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9113 - department_output_loss: 0.5941 - attrition_output_loss: 0.3171 - department_output_accuracy: 0.7604 - attrition_output_accuracy: 0.8802
# Epoch 34/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8977 - department_output_loss: 0.5845 - attrition_output_loss: 0.3131 - department_output_accuracy: 0.7659 - attrition_output_accuracy: 0.8857
# Epoch 35/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8931 - department_output_loss: 0.5789 - attrition_output_loss: 0.3142 - department_output_accuracy: 0.7677 - attrition_output_accuracy: 0.8820
# Epoch 36/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8794 - department_output_loss: 0.5703 - attrition_output_loss: 0.3091 - department_output_accuracy: 0.7713 - attrition_output_accuracy: 0.8802
# Epoch 37/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8708 - department_output_loss: 0.5643 - attrition_output_loss: 0.3065 - department_output_accuracy: 0.7786 - attrition_output_accuracy: 0.8875
# Epoch 38/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8636 - department_output_loss: 0.5613 - attrition_output_loss: 0.3023 - department_output_accuracy: 0.7768 - attrition_output_accuracy: 0.8829
# Epoch 39/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8527 - department_output_loss: 0.5522 - attrition_output_loss: 0.3005 - department_output_accuracy: 0.7813 - attrition_output_accuracy: 0.8866
# Epoch 40/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8393 - department_output_loss: 0.5406 - attrition_output_loss: 0.2987 - department_output_accuracy: 0.7868 - attrition_output_accuracy: 0.8884
# Epoch 41/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8301 - department_output_loss: 0.5343 - attrition_output_loss: 0.2958 - department_output_accuracy: 0.7967 - attrition_output_accuracy: 0.8893
# Epoch 42/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8185 - department_output_loss: 0.5254 - attrition_output_loss: 0.2931 - department_output_accuracy: 0.8013 - attrition_output_accuracy: 0.8902
# Epoch 43/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8157 - department_output_loss: 0.5260 - attrition_output_loss: 0.2897 - department_output_accuracy: 0.7995 - attrition_output_accuracy: 0.8911
# Epoch 44/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8172 - department_output_loss: 0.5285 - attrition_output_loss: 0.2887 - department_output_accuracy: 0.7858 - attrition_output_accuracy: 0.8929
# Epoch 45/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.7957 - department_output_loss: 0.5092 - attrition_output_loss: 0.2865 - department_output_accuracy: 0.8085 - attrition_output_accuracy: 0.8929
# Epoch 46/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.7869 - department_output_loss: 0.5010 - attrition_output_loss: 0.2859 - department_output_accuracy: 0.8113 - attrition_output_accuracy: 0.8902
# Epoch 47/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.7811 - department_output_loss: 0.4995 - attrition_output_loss: 0.2816 - department_output_accuracy: 0.8049 - attrition_output_accuracy: 0.8938
# Epoch 48/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.7674 - department_output_loss: 0.4908 - attrition_output_loss: 0.2766 - department_output_accuracy: 0.8122 - attrition_output_accuracy: 0.8956
# Epoch 49/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.7607 - department_output_loss: 0.4849 - attrition_output_loss: 0.2758 - department_output_accuracy: 0.8176 - attrition_output_accuracy: 0.8929
# Epoch 50/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.7511 - department_output_loss: 0.4767 - attrition_output_loss: 0.2744 - department_output_accuracy: 0.8176 - attrition_output_accuracy: 0.8938

# %%
# Evaluate the model with the testing data
model_loss, dept_loss, attr_loss, dept_acc, attr_acc = model.evaluate(X_test_scaled,
                                                                      {'department_output': y_test_dept,
                                                                       'attrition_output': y_test_attr})

# Print the accuracy for both department and attrition
print(f"Department predictions accuracy: {dept_acc}")
print(f"Attrition predictions accuracy: {attr_acc}")
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5128 - department_output_loss: 1.0502 - attrition_output_loss: 0.4626 - department_output_accuracy: 0.5543 - attrition_output_accuracy: 0.8234
# Department predictions accuracy: 0.554347813129425
# Attrition predictions accuracy: 0.823369562625885

# %%
# Part 3: Summary

# 1. Is accuracy the best metric to use on this data? Why or why not?
'''
Accuracy can be a good starting point, but it may not be the best metric for this problem.
The attrition data might be imbalanced, meaning there could be significantly more employees
who haven't left the company compared to those who have. In such cases, metrics like
precision, recall, or F1-score might provide better insights into the model's performance.
Additionally, the cost of misclassifying an employee who is likely to leave versus one who
is likely to stay could be different, so metrics that take this into account, like
cost-sensitive accuracy or ROC AUC, could be more appropriate.
'''

# 2. What activation functions did you choose for your output layers, and why?
'''
For the Department output, I used the softmax activation function because it is suitable
for multi-class classification problems. Softmax ensures that the output probabilities
for each class sum up to 1, providing a clear interpretation of the predicted class.

For the Attrition output, I used the sigmoid activation function since attrition is a
binary classification problem (leave or stay). Sigmoid maps the output to a probability
between 0 and 1, which aligns well with the binary nature of the problem.
'''

# 3. Can you name a few ways that this model might be improved?
'''
Some ways to potentially improve the model:

1. Hyperparameter tuning: Experiment with different architectures, number of layers,
   units per layer, learning rates, batch sizes, and other hyperparameters to find
   the optimal configuration.

2. Feature selection/engineering: Analyze the importance of each feature and consider
   removing less informative ones. Create new features through combinations or
   transformations of existing features.

3. Handling class imbalance: If the attrition classes are imbalanced, techniques like
   oversampling the minority class, undersampling the majority class, or using class
   weights during training can help improve performance.

4. Regularization: Apply regularization techniques like L1/L2 regularization or dropout
   to prevent overfitting and improve generalization.

5. Ensemble methods: Train multiple models with different architectures or on different
   subsets of the data and combine their predictions to make more robust predictions.
'''
# Out:
# '\nSome ways to potentially improve the model:\n\n1. Hyperparameter tuning: Experiment with different architectures, number of layers, \n   units per layer, learning rates, batch sizes, and other hyperparameters to find \n   the optimal configuration.\n\n2. Feature selection/engineering: Analyze the importance of each feature and consider \n   removing less informative ones. Create new features through combinations or \n   transformations of existing features.\n\n3. Handling class imbalance: If the attrition classes are imbalanced, techniques like \n   oversampling the minority class, undersampling the majority class, or using class \n   weights during training can help improve performance.\n\n4. Regularization: Apply regularization techniques like L1/L2 regularization or dropout \n   to prevent overfitting and improve generalization.\n\n5. Ensemble methods: Train multiple models with different architectures or on different \n   subsets of the data and combine their predictions to make more robust predictions.\n'
